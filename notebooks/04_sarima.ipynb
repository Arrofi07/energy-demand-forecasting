# %% [markdown]
# # Phase 4 — SARIMA Baseline

# %%
import sys
sys.path.insert(0, '..')
from src.data.loader import load_processed
from src.models.sarima_model import fit_sarima, forecast_sarima
from src.evaluation.metrics import evaluate_all

# %%
df = load_processed()
hourly = df['Global_active_power'].resample('h').mean().dropna()

# %%
train = hourly[:'2009-12-31']
test = hourly['2010-01-01':'2010-01-31']

model = fit_sarima(train)
preds = forecast_sarima(model, horizon=len(test))
evaluate_all(test.values, preds.values)
# Out:
# /Users/apple/Documents/Projects/energy-demand-forecasting/.venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/apple/Documents/Projects/energy-demand-forecasting/.venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/apple/Documents/Projects/energy-demand-forecasting/.venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# ...
